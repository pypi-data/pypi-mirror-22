# %%
# import sys
# sys.path.append('/Users/alex/Documents/OpenPIV/openpiv-python')
import openpiv.tools, openpiv.process, openpiv.scaling, openpiv.validation, openpiv.filters


import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
frame_a  = openpiv.tools.imread( 'exp1_001_a.bmp' )
frame_b  = openpiv.tools.imread( 'exp1_001_b.bmp' )

# we want to test the overlap only, so we take a small image and check the result for overlaps
frame_a = frame_a[:128,:128]
frame_b = frame_b[:128,:128]

# %%
fig,ax = plt.subplots(1,2)
ax[0].imshow(frame_a,cmap=plt.cm.gray)
ax[1].imshow(frame_b,cmap=plt.cm.gray)

# %%
winsize = 64 # pixels
searchsize = 64  # pixels, search in image B
overlap = 32 # pixels
dt = 1 # sec

u0, v0, sig2noise = openpiv.process.extended_search_area_piv( frame_a.astype(np.int32), frame_b.astype(np.int32), window_size=winsize, overlap=overlap, dt=dt, search_area_size=searchsize, sig2noise_method='peak2peak' )

# %%
x, y = openpiv.process.get_coordinates( image_size=frame_a.shape, window_size=winsize, overlap=overlap )

# %%
u1, v1, mask = openpiv.validation.sig2noise_val( u0, v0, sig2noise, threshold = 1.3 )
print np.nansum((u1 - u0)**2)
# Out:
# 0.0

# %%
u2, v2 = openpiv.filters.replace_outliers( u1, v1, method='localmean', max_iter=10, kernel_size=2)
print np.nansum((u2 - u1)**2)
# Out:
# 0.0

# %%
x, y, u3, v3 = openpiv.scaling.uniform(x, y, u2, v2, scaling_factor = 1 )
print np.nansum((u3 - u2)**2)
# Out:
# 0.0

# %%
openpiv.tools.save(x, y, u3, v3, mask, 'exp1_001.txt' )

# %%
openpiv.tools.display_vector_field('exp1_001.txt', scale=100, width=0.0025)

# %%
x
# Out:
# array([[ 31.5,  63.5,  95.5],
#        [ 31.5,  63.5,  95.5],
#        [ 31.5,  63.5,  95.5]])

# %%
y
# Out:
# array([[ 95.5,  95.5,  95.5],
#        [ 63.5,  63.5,  63.5],
#        [ 31.5,  31.5,  31.5]])

# %%
field_shape = openpiv.process.get_field_shape( image_size =  frame_a.shape, window_size = winsize, overlap = overlap )
print(field_shape)
# Out:
# (3, 3)

# %%
field_shape = openpiv.process.get_field_shape( image_size =  frame_a.shape, window_size = winsize, overlap = 0 )
print(field_shape)
# Out:
# (2, 2)

# %%
field_shape = openpiv.process.get_field_shape( image_size =  frame_a.shape, window_size = winsize, overlap = 63 )
print(field_shape)
# Out:
# (65, 65)
